# %%
#import pip
## import seaborn
#pip.main(['install','seaborn'])

# %%
import numpy as np 
import pandas as pd 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import math
import time
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors
import sklearn.externals
import joblib
import scipy.sparse
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import svds
import warnings; warnings.simplefilter('ignore')
# %matplotlib inline

# %% [markdown]
# ## Model-based collaborative filtering system

# %%
file_one = '../Resources/merged.csv'
data = pd.read_csv(file_one) 
data.head()
# Out:
#         date        asin            user  rating     timestamp    ts_date
# 0   2-Oct-13  9875851809  A33YTN2JLRR53E     5.0  1.535587e+09  8/30/2018
# 1   4-Sep-73  B000068NXO  A2Q8TMZVWG7M8C     5.0  1.535155e+09  8/25/2018
# 2   4-Sep-73  B000068NXO  A2Q8TMZVWG7M8C     5.0  1.535155e+09  8/25/2018
# 3  13-Oct-17  1609319745   AHH7D9X7GMN53     5.0  1.534810e+09  8/21/2018
# 4  28-Nov-12  1309810397  A3CB1W1O9Z57VN     5.0  1.534378e+09  8/16/2018

# %%
df = data[['asin', 'user', 'rating']] 
df.head()
# Out:
#          asin            user  rating
# 0  9875851809  A33YTN2JLRR53E     5.0
# 1  B000068NXO  A2Q8TMZVWG7M8C     5.0
# 2  B000068NXO  A2Q8TMZVWG7M8C     5.0
# 3  1609319745   AHH7D9X7GMN53     5.0
# 4  1309810397  A3CB1W1O9Z57VN     5.0

# %%
#The dataset is a 1042868 x 3 matrix
df.shape
# Out:
# (1042868, 3)

# %%
df.dtypes
# Out:
# asin       object
# user       object
# rating    float64
# dtype: object

# %%
# Look at Statistics of the rating variable
df.describe()['rating'].T
# Out:
# count    877951.000000
# mean          4.177560
# std           1.298668
# min           1.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
#Find the min and max of rating
print('Minimum rating is: %d' %(df.rating.min()))
print('Maximum rating is: %d' %(df.rating.max()))
# Out:
# Minimum rating is: 1
# Maximum rating is: 5

# %%
#Check for missing values
print('Number of missing values across columns: \n',df.isnull().sum())
# Out:
# Number of missing values across columns:
#  asin      164917
# user      164917
# rating    164917
# dtype: int64

# %%
#
df1= df.dropna()
df1.head()
# Out:
#          asin            user  rating
# 0  9875851809  A33YTN2JLRR53E     5.0
# 1  B000068NXO  A2Q8TMZVWG7M8C     5.0
# 2  B000068NXO  A2Q8TMZVWG7M8C     5.0
# 3  1609319745   AHH7D9X7GMN53     5.0
# 4  1309810397  A3CB1W1O9Z57VN     5.0

# %%
#Check for missing values
print('Number of missing values across columns: \n',df1.isnull().sum())
# Out:
# Number of missing values across columns:
#  asin      0
# user      0
# rating    0
# dtype: int64

# %%
print("Total data")
print("-"*50)
print("\nTotal no of ratings :",df1.shape[0])
print("Total No of Users   :", len(np.unique(df1.user)))
print("Total No of products  :", len(np.unique(df1.asin)))
# Out:
# Total data
# --------------------------------------------------
#
# Total no of ratings : 877951
# Total No of Users   : 376533
# Total No of products  : 16639

# %%
#Analysis of rating given by the user 
#Rank users by the number of ratings they made descending

rated_per_user = df1.groupby(by='user')['rating'].count().sort_values(ascending=False)

rated_per_user.head()
# Out:
# user
# A2R6RA8FRBS608    73
# A2AY4YUOX2N1BQ    72
# A3OXHLG6DIBRW8    64
# A203OCQQ12MAVT    64
# AGXV8E7XK9J6H     62
# Name: rating, dtype: int64

# %%
quantiles = rated_per_user.quantile(np.arange(0,1.01,0.01), interpolation='higher')

# %%
#Within rated products,find number of products have less than 10 ratings
print('\n No of rated product more than 20 per user : {}\n'.format(sum(rated_per_user >= 20)) )
# Out:
#  No of rated product more than 20 per user : 179

# %%
# new_df = df1.groupby("user").filter(lambda x:x['rating'].count() >=20)
# new_df.head(50)

# %%
#Create a user x product ID matrix

new_df = df1.head(5000)
ratings_matrix = new_df.pivot_table(values='rating', index='user', columns='asin', fill_value=0)
ratings_matrix.head(50)
# Out:
# asin                  105997231X  106171327X  1309810397  1400501466  \
# user
# A0455748DCIEXIHB3PIV           0           0           0           0
# A09225229MO7JS8WEWGW           0           0           0           0
# A1028XZRNI0NRP                 0           0           0           0
# A102P6D3352JLV                 0           0           0           0
# A103BWSSSROFA                  0           0           0           0
# A104GZA57WRQU4                 0           0           0           0
# A106NDT51Z7TCN                 0           0           0           0
# A1089L6OD3HW1F                 0           0           0           0
# A108NEP41RV059                 0           0           0           0
# A108OD7EV20KAU                 0           0           0           0
# A108SWXE6QIO1E                 0           0           0           0
# A109R594DZJN63                 0           0           0           0
# A10A7L1OVQFG4O                 0           0           0           0
# A10BNT57AVFPUG                 0           0           0           0
# A10EE8SNILHYVE                 0           0           0           0
# A10FU26TXJF2PH                 0           0           0           0
# A10G9WYVDAMO3A                 0           0           0           0
# A10KXIN9X45WHV                 0           0           0           0
# A10OO3FNJIAXOZ                 0           0           0           0
# A10PRJAYW45LK0                 0           0           0           0
# A10SE0U42ABS9S                 0           0           0           0
# A111YF0NJYRIO0                 0           0           0           0
# A116FN2JCDA75D                 0           0           0           0
# A11BCJ8Q56BOOT                 0           0           0           0
# A11FU01L5W6JQ                  0           0           0           0
# A11GVJ0O3EBG1H                 0           0           0           0
# A11MAMA4MMJ3HI                 0           0           0           0
# A11QGEAG1QEYQE                 0           0           0           0
# A11RP9Q3S6IIMD                 0           0           0           0
# A11TAI1OSFGWLD                 0           0           0           0
# A11UE51T70KLSD                 0           0           0           0
# A126LK7XPATVKV                 0           0           0           0
# A12CI8MQGCZP2D                 0           0           0           0
# A12D4TJ9ON1U4M                 0           0           0           0
# A12ETLF9SD545A                 0           0           0           0
# A12JSE5PCWN38H                 0           0           0           0
# A12KR9LFVW8K7U                 0           0           0           0
# A12KUBFZDNGTQ1                 0           0           0           0
# A12O5BKQ5VXMJB                 0           0           0           0
# A12OGO287QAB5H                 0           0           0           0
# A12OGR0B5CB99I                 0           0           0           0
# A12PJ0VUUI3UOZ                 0           0           0           0
# A12UZQEWCHHY8Y                 0           0           0           0
# A12VOLVO7YGT47                 0           0           0           0
# A12XRTLO5VBCLP                 0           0           0           0
# A12Y9MJQ5HQQ6A                 0           0           0           0
# A12Z45PVP4UPO1                 0           0           0           0
# A132UJ089FKIZV                 0           0           0           0
# A133ROIZDYV2CJ                 0           0           0           0
# A136K15R596IJ                  0           0           0           0
#
# asin                  1400697492  1503716821  1609319745  161685572X  \
# user
# A0455748DCIEXIHB3PIV           0           0           0           0
# A12OGO287QAB5H                 0           0           0           0
# A12OGR0B5CB99I                 0           0           0           0
# A12PJ0VUUI3UOZ                 0           0           0           0
# A12UZQEWCHHY8Y                 0           0           0           0
# A12VOLVO7YGT47                 0           0           0           0
# A12XRTLO5VBCLP                 0           0           0           0
# A12Y9MJQ5HQQ6A                 0           0           0           0
# A12Z45PVP4UPO1                 0           0           0           0
# A132UJ089FKIZV                 0           0           0           0
# A133ROIZDYV2CJ                 0           0           0           0
# A136K15R596IJ                  0           0           0           0
#
# [50 rows x 872 columns]

# %%
#Total 2408 rows and 872 columns in the matrix
ratings_matrix.shape
# Out:
# (2408, 872)

# %%
# Transpose the previous matrix
X = ratings_matrix.T
X.head()
# Out:
# user        A0455748DCIEXIHB3PIV  A09225229MO7JS8WEWGW  A1028XZRNI0NRP  \
# asin
# 105997231X                     0                     0               0
# 106171327X                     0                     0               0
# 1309810397                     0                     0               0
# 1400501466                     0                     0               0
# 1400697492                     0                     0               0
#
# user        A102P6D3352JLV  A103BWSSSROFA  A104GZA57WRQU4  A106NDT51Z7TCN  \
# asin
# 105997231X               0              0               0               0
# 106171327X               0              0               0               0
# 1309810397               0              0               0               0
# 1400501466               0              0               0               0
# 1400697492               0              0               0               0
#
# user        A1089L6OD3HW1F  A108NEP41RV059  A108OD7EV20KAU  ...  \
# asin                                                        ...
# 105997231X               0               0               0  ...
# 106171327X               0               0               0  ...
# 1309810397               0               0               0  ...
# 1400501466               0               0               0  ...
# 1400697492               0               0               0  ...
#
# user        AZC7NNERBVMRN  AZE0KIKKJWB49  AZFMALF6H3TPH  AZG5BAZ7DZ6UA  \
# asin
# 105997231X              0              0              0              0
# 106171327X              0              0              0              0
# 1309810397              0              0              0              0
# 1400501466              0              0              0              0
# 1400697492              0              0              0              0
#
# user        AZIRYNX93E5XT  AZJWR2IABF58P  AZM3NKUMUJ66X  AZP80AOLJ4KR1  \
# asin
# 105997231X              0              0              0              0
# 106171327X              0              0              0              0
# 1309810397              0              0              0              0
# 1400501466              0              0              0              0
# 1400697492              0              0              0              0
#
# user        AZRE080M2B9TW  AZWMPLVQQ6QWP
# asin
# 105997231X              0              0
# 106171327X              0              0
# 1309810397              0              0
# 1400501466              0              0
# 1400697492              0              0
#
# [5 rows x 2408 columns]

# %%
#We have 872 unique products, 2408 unique users who gave product ratings

X.shape
# Out:
# (872, 2408)

# %%
X1 = X

# %%
#Decomposing the Matrix
from sklearn.decomposition import TruncatedSVD
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (872, 10)

# %%
#Correlation Matrix

correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (872, 872)

# %%
X.index[150]
# Out:
# 'B00004TDA2'

# %%
i = "B00004TDA2"

product_id = list(X.index)
asin_id = product_id.index(i)
asin_id
# Out:
# 150

# %%
correlation_asin_id = correlation_matrix[asin_id]
correlation_asin_id.shape
# Out:
# (872,)

# %%
Recommend = list(X.index[correlation_asin_id > 0.65])

# Removes the purchased item 
Recommend.remove(i) 

Recommend[0:10]
# Out:
# ['692056343',
#  '9714971608',
#  '9875971812',
#  '9876219502',
#  '9966624805',
#  '9967222204',
#  '9984984354',
#  'B000001OMW',
#  'B00000J1EJ',
#  'B00000J1T1']

# %% [markdown]
# ## Popularity Based Recommendation

# %%
import matplotlib.pyplot as plt

# %%
#Getting the new dataframe which contains users who has given 50 or more ratings
new_df=data.groupby("asin").filter(lambda x:x['rating'].count() >=50)

# %%
new_df.head()
# Out:
#         date        asin            user  rating     timestamp    ts_date
# 70  4-Sep-99  B00004YK4I  A1NPNHYYBU56F5     4.0  1.527034e+09  5/23/2018
# 71  4-Sep-99  B00004YK4I  A1NPNHYYBU56F5     4.0  1.527034e+09  5/23/2018
# 73  4-Sep-99  B00004YK4I  A1XIW68U4UUTYD     5.0  1.526947e+09  5/22/2018
# 74  4-Sep-99  B00004YK4I  A1XIW68U4UUTYD     5.0  1.526947e+09  5/22/2018
# 77  7-Jul-04  B000067SBX  A16VTLGFC51E0W     5.0  1.526861e+09  5/21/2018

# %%
no_of_ratings_per_product = new_df.groupby(by='asin')['rating'].count().sort_values(ascending=False)

fig = plt.figure(figsize=plt.figaspect(.5))
ax = plt.gca()
plt.plot(no_of_ratings_per_product.values)
plt.title('# RATINGS per Product')
plt.xlabel('Product')
plt.ylabel('No of ratings per product')
ax.set_xticklabels([])

plt.show()
# Out:
# Text(0.5, 1.0, '# RATINGS per Product')
# Text(0.5, 0, 'Product')
# Text(0, 0.5, 'No of ratings per product')
# [Text(-250.0, 0, ''),
#  Text(0.0, 0, ''),
#  Text(250.0, 0, ''),
#  Text(500.0, 0, ''),
#  Text(750.0, 0, ''),
#  Text(1000.0, 0, ''),
#  Text(1250.0, 0, ''),
#  Text(1500.0, 0, ''),
#  Text(1750.0, 0, ''),
#  Text(2000.0, 0, ''),
#  Text(2250.0, 0, '')]

# %%
#Average rating of the product
new_df.groupby('asin')['rating'].mean().head()
# Out:
# asin
# 059449771X    4.198473
# 101635370     2.910256
# 1059844575    2.468354
# 1060078031    3.873418
# 106171327X    4.436718
# Name: rating, dtype: float64

# %%
new_df.groupby('asin')['rating'].mean().sort_values(ascending=False).head()
# Out:
# asin
# B00008VSKS    5.000000
# B00005BJEM    5.000000
# B00000J0MS    4.997555
# 1630460001    4.983333
# B0000AE6AK    4.960000
# Name: rating, dtype: float64

# %%
#Total no of rating for product

new_df.groupby('asin')['rating'].count().sort_values(ascending=False).head()
# Out:
# asin
# B00004ZCJJ    11390
# B00004ZCJI    11390
# B00009KLAE    11378
# B00007M1TZ    10530
# B00007E7JU     9324
# Name: rating, dtype: int64

# %%
ratings_mean_count = pd.DataFrame(new_df.groupby('asin')['rating'].mean())

# %%
ratings_mean_count['rating_counts'] = pd.DataFrame(new_df.groupby('asin')['rating'].count())

# %%
ratings_mean_count.head()
# Out:
#               rating  rating_counts
# asin
# 059449771X  4.198473            131
# 101635370   2.910256             78
# 1059844575  2.468354            237
# 1060078031  3.873418            158
# 106171327X  4.436718            719

# %%
#Max number of ratings for a product
ratings_mean_count['rating_counts'].max()
# Out:
# 11390

# %%
plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
ratings_mean_count['rating_counts'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
ratings_mean_count['rating'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
sns.jointplot(x='rating', y='rating_counts', data=ratings_mean_count, alpha=0.4)

# %%
popular_products = pd.DataFrame(new_df.groupby('asin')['rating'].count())
most_popular = popular_products.sort_values('rating', ascending=False)
most_popular.head(30).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='asin'>
